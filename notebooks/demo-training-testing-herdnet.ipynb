# %% [markdown]
# # DEMO - Training and testing HerdNet on nadir aerial images

# %% [markdown]
# ## Installations

# %%
# Check GPU
# !nvidia-smi
# Out:
# Wed Jan 28 16:37:56 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Install the dependencies
# !pip install \
    timm==1.0.22 \
    albumentations==1.0.3 \
    hydra-core==1.3.2 \
    opencv-python==4.10.0.84 \
    pillow==10.4.0 \
    scikit-image \
    scikit-learn \
    wandb==0.20.1 \
    gdown==5.2.0 \
    matplotlib==3.10.8 \
    tqdm==4.67.1 \
    loguru==0.7.3 \
    seaborn==0.13.2 \
    numpy==2.4.1 \
    scipy==1.16.0 \
    pandas==2.3.1
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: timm==1.0.22 in /usr/local/lib/python3.12/dist-packages (1.0.22)
# Requirement already satisfied: albumentations==1.0.3 in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: hydra-core==1.3.2 in /usr/local/lib/python3.12/dist-packages (1.3.2)
# Requirement already satisfied: opencv-python==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (4.10.0.84)
# Requirement already satisfied: pillow==10.4.0 in /usr/local/lib/python3.12/dist-packages (10.4.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: wandb==0.20.1 in /usr/local/lib/python3.12/dist-packages (0.20.1)
# Requirement already satisfied: gdown==5.2.0 in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: matplotlib==3.10.8 in /usr/local/lib/python3.12/dist-packages (3.10.8)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: loguru==0.7.3 in /usr/local/lib/python3.12/dist-packages (0.7.3)
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy==2.4.1 in /usr/local/lib/python3.12/dist-packages (2.4.1)
# Requirement already satisfied: scipy==1.16.0 in /usr/local/lib/python3.12/dist-packages (1.16.0)
# Requirement already satisfied: pandas==2.3.1 in /usr/local/lib/python3.12/dist-packages (2.3.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from timm==1.0.22) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm==1.0.22) (0.24.0+cu126)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm==1.0.22) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm==1.0.22) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm==1.0.22) (0.7.0)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from albumentations==1.0.3) (4.13.0.90)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core==1.3.2) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core==1.3.2) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from hydra-core==1.3.2) (25.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb==0.20.1) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.20.1) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb==0.20.1) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.20.1) (5.29.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.20.1) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb==0.20.1) (2.12.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.20.1) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.20.1) (2.49.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.12/dist-packages (from wandb==0.20.1) (1.3.7)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb==0.20.1) (4.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown==5.2.0) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown==5.2.0) (3.20.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.8) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.8) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.8) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.8) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.8) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.1) (2025.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2026.1.14)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.20.1) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb==0.20.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb==0.20.1) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb==0.20.1) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.10.8) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.20.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.20.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.20.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.20.1) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown==5.2.0) (2.8.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm==1.0.22) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm==1.0.22) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==5.2.0) (1.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->timm==1.0.22) (3.5.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.20.1) (5.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->timm==1.0.22) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->timm==1.0.22) (3.0.3)

# %%
# Download and install the code
import sys

# !git clone https://github.com/Alexandre-Delplanque/HerdNet
# !cd '/content/HerdNet' && python setup.py install

sys.path.append('/content/HerdNet')
# Out:
# fatal: destination path 'HerdNet' already exists and is not an empty directory.
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing animaloc.egg-info/PKG-INFO
# writing dependency_links to animaloc.egg-info/dependency_links.txt
# writing top-level names to animaloc.egg-info/top_level.txt
# reading manifest file 'animaloc.egg-info/SOURCES.txt'
# writing manifest file 'animaloc.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying animaloc/__init__.py -> build/lib/animaloc
# copying animaloc/vizual/__init__.py -> build/lib/animaloc/vizual
# copying animaloc/vizual/objects.py -> build/lib/animaloc/vizual
# copying animaloc/vizual/image.py -> build/lib/animaloc/vizual
# copying animaloc/vizual/plots.py -> build/lib/animaloc/vizual
# copying animaloc/datasets/patched.py -> build/lib/animaloc/datasets
# copying animaloc/datasets/folder.py -> build/lib/animaloc/datasets
# copying animaloc/datasets/register.py -> build/lib/animaloc/datasets
# copying animaloc/datasets/__init__.py -> build/lib/animaloc/datasets
# copying animaloc/datasets/csv.py -> build/lib/animaloc/datasets
# copying animaloc/data/utils.py -> build/lib/animaloc/data
# copying animaloc/data/patches.py -> build/lib/animaloc/data
# copying animaloc/data/transforms.py -> build/lib/animaloc/data
# copying animaloc/data/processors.py -> build/lib/animaloc/data
# copying animaloc/data/samplers.py -> build/lib/animaloc/data
# copying animaloc/data/annotations.py -> build/lib/animaloc/data
# copying animaloc/data/__init__.py -> build/lib/animaloc/data
# copying animaloc/data/types.py -> build/lib/animaloc/data
# copying animaloc/data/batch_utils.py -> build/lib/animaloc/data
# copying animaloc/utils/seed.py -> build/lib/animaloc/utils
# copying animaloc/utils/timer.py -> build/lib/animaloc/utils
# copying animaloc/utils/torchvision_utils.py -> build/lib/animaloc/utils
# copying animaloc/utils/__init__.py -> build/lib/animaloc/utils
# copying animaloc/utils/logger.py -> build/lib/animaloc/utils
# copying animaloc/utils/registry.py -> build/lib/animaloc/utils
# copying animaloc/utils/useful_funcs.py -> build/lib/animaloc/utils
# copying animaloc/eval/utils.py -> build/lib/animaloc/eval
# copying animaloc/eval/__init__.py -> build/lib/animaloc/eval
# copying animaloc/eval/lmds.py -> build/lib/animaloc/eval
# copying animaloc/eval/stitchers.py -> build/lib/animaloc/eval
# copying animaloc/eval/evaluators.py -> build/lib/animaloc/eval
# copying animaloc/eval/metrics.py -> build/lib/animaloc/eval
# copying animaloc/models/utils.py -> build/lib/animaloc/models
# copying animaloc/models/faster_rcnn.py -> build/lib/animaloc/models
# copying animaloc/models/register.py -> build/lib/animaloc/models
# copying animaloc/models/__init__.py -> build/lib/animaloc/models
# copying animaloc/models/herdnet.py -> build/lib/animaloc/models
# copying animaloc/models/dla.py -> build/lib/animaloc/models
# copying animaloc/models/ss_dla.py -> build/lib/animaloc/models
# copying animaloc/train/__init__.py -> build/lib/animaloc/train
# copying animaloc/train/trainers.py -> build/lib/animaloc/train
# copying animaloc/train/adaloss.py -> build/lib/animaloc/train
# copying animaloc/train/losses/register.py -> build/lib/animaloc/train/losses
# copying animaloc/train/losses/__init__.py -> build/lib/animaloc/train/losses
# copying animaloc/train/losses/ssim.py -> build/lib/animaloc/train/losses
# copying animaloc/train/losses/focal.py -> build/lib/animaloc/train/losses
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/animaloc
# creating build/bdist.linux-x86_64/egg/animaloc/vizual
# copying build/lib/animaloc/vizual/__init__.py -> build/bdist.linux-x86_64/egg/animaloc/vizual
# copying build/lib/animaloc/vizual/objects.py -> build/bdist.linux-x86_64/egg/animaloc/vizual
# copying build/lib/animaloc/vizual/image.py -> build/bdist.linux-x86_64/egg/animaloc/vizual
# copying build/lib/animaloc/vizual/plots.py -> build/bdist.linux-x86_64/egg/animaloc/vizual
# copying build/lib/animaloc/__init__.py -> build/bdist.linux-x86_64/egg/animaloc
# creating build/bdist.linux-x86_64/egg/animaloc/datasets
# copying build/lib/animaloc/datasets/patched.py -> build/bdist.linux-x86_64/egg/animaloc/datasets
# copying build/lib/animaloc/datasets/folder.py -> build/bdist.linux-x86_64/egg/animaloc/datasets
# copying build/lib/animaloc/datasets/register.py -> build/bdist.linux-x86_64/egg/animaloc/datasets
# copying build/lib/animaloc/datasets/__init__.py -> build/bdist.linux-x86_64/egg/animaloc/datasets
# copying build/lib/animaloc/datasets/csv.py -> build/bdist.linux-x86_64/egg/animaloc/datasets
# creating build/bdist.linux-x86_64/egg/animaloc/data
# copying build/lib/animaloc/data/utils.py -> build/bdist.linux-x86_64/egg/animaloc/data
# copying build/lib/animaloc/data/patches.py -> build/bdist.linux-x86_64/egg/animaloc/data
# copying build/lib/animaloc/data/transforms.py -> build/bdist.linux-x86_64/egg/animaloc/data
# copying build/lib/animaloc/data/processors.py -> build/bdist.linux-x86_64/egg/animaloc/data
# copying build/lib/animaloc/data/samplers.py -> build/bdist.linux-x86_64/egg/animaloc/data
# copying build/lib/animaloc/data/annotations.py -> build/bdist.linux-x86_64/egg/animaloc/data
# copying build/lib/animaloc/data/__init__.py -> build/bdist.linux-x86_64/egg/animaloc/data
# copying build/lib/animaloc/data/types.py -> build/bdist.linux-x86_64/egg/animaloc/data
# copying build/lib/animaloc/data/batch_utils.py -> build/bdist.linux-x86_64/egg/animaloc/data
# creating build/bdist.linux-x86_64/egg/animaloc/utils
# copying build/lib/animaloc/utils/seed.py -> build/bdist.linux-x86_64/egg/animaloc/utils
# copying build/lib/animaloc/utils/timer.py -> build/bdist.linux-x86_64/egg/animaloc/utils
# copying build/lib/animaloc/utils/torchvision_utils.py -> build/bdist.linux-x86_64/egg/animaloc/utils
# copying build/lib/animaloc/utils/__init__.py -> build/bdist.linux-x86_64/egg/animaloc/utils
# copying build/lib/animaloc/utils/logger.py -> build/bdist.linux-x86_64/egg/animaloc/utils
# copying build/lib/animaloc/utils/registry.py -> build/bdist.linux-x86_64/egg/animaloc/utils
# copying build/lib/animaloc/utils/useful_funcs.py -> build/bdist.linux-x86_64/egg/animaloc/utils
# creating build/bdist.linux-x86_64/egg/animaloc/eval
# copying build/lib/animaloc/eval/utils.py -> build/bdist.linux-x86_64/egg/animaloc/eval
# copying build/lib/animaloc/eval/__init__.py -> build/bdist.linux-x86_64/egg/animaloc/eval
# copying build/lib/animaloc/eval/lmds.py -> build/bdist.linux-x86_64/egg/animaloc/eval
# copying build/lib/animaloc/eval/stitchers.py -> build/bdist.linux-x86_64/egg/animaloc/eval
# copying build/lib/animaloc/eval/evaluators.py -> build/bdist.linux-x86_64/egg/animaloc/eval
# copying build/lib/animaloc/eval/metrics.py -> build/bdist.linux-x86_64/egg/animaloc/eval
# creating build/bdist.linux-x86_64/egg/animaloc/models
# copying build/lib/animaloc/models/utils.py -> build/bdist.linux-x86_64/egg/animaloc/models
# copying build/lib/animaloc/models/faster_rcnn.py -> build/bdist.linux-x86_64/egg/animaloc/models
# copying build/lib/animaloc/models/register.py -> build/bdist.linux-x86_64/egg/animaloc/models
# copying build/lib/animaloc/models/__init__.py -> build/bdist.linux-x86_64/egg/animaloc/models
# copying build/lib/animaloc/models/herdnet.py -> build/bdist.linux-x86_64/egg/animaloc/models
# copying build/lib/animaloc/models/dla.py -> build/bdist.linux-x86_64/egg/animaloc/models
# copying build/lib/animaloc/models/ss_dla.py -> build/bdist.linux-x86_64/egg/animaloc/models
# creating build/bdist.linux-x86_64/egg/animaloc/train
# copying build/lib/animaloc/train/__init__.py -> build/bdist.linux-x86_64/egg/animaloc/train
# creating build/bdist.linux-x86_64/egg/animaloc/train/losses
# copying build/lib/animaloc/train/losses/register.py -> build/bdist.linux-x86_64/egg/animaloc/train/losses
# copying build/lib/animaloc/train/losses/__init__.py -> build/bdist.linux-x86_64/egg/animaloc/train/losses
# copying build/lib/animaloc/train/losses/ssim.py -> build/bdist.linux-x86_64/egg/animaloc/train/losses
# copying build/lib/animaloc/train/losses/focal.py -> build/bdist.linux-x86_64/egg/animaloc/train/losses
# copying build/lib/animaloc/train/trainers.py -> build/bdist.linux-x86_64/egg/animaloc/train
# copying build/lib/animaloc/train/adaloss.py -> build/bdist.linux-x86_64/egg/animaloc/train
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/vizual/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/vizual/objects.py to objects.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/vizual/image.py to image.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/vizual/plots.py to plots.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/datasets/patched.py to patched.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/datasets/folder.py to folder.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/datasets/register.py to register.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/datasets/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/datasets/csv.py to csv.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/data/utils.py to utils.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/data/patches.py to patches.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/data/transforms.py to transforms.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/data/processors.py to processors.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/data/samplers.py to samplers.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/data/annotations.py to annotations.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/data/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/data/types.py to types.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/data/batch_utils.py to batch_utils.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/utils/seed.py to seed.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/utils/timer.py to timer.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/utils/torchvision_utils.py to torchvision_utils.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/utils/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/utils/logger.py to logger.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/utils/registry.py to registry.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/utils/useful_funcs.py to useful_funcs.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/eval/utils.py to utils.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/eval/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/eval/lmds.py to lmds.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/eval/stitchers.py to stitchers.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/eval/evaluators.py to evaluators.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/eval/metrics.py to metrics.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/models/utils.py to utils.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/models/faster_rcnn.py to faster_rcnn.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/models/register.py to register.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/models/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/models/herdnet.py to herdnet.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/models/dla.py to dla.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/models/ss_dla.py to ss_dla.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/train/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/train/losses/register.py to register.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/train/losses/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/train/losses/ssim.py to ssim.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/train/losses/focal.py to focal.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/train/trainers.py to trainers.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/animaloc/train/adaloss.py to adaloss.cpython-312.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying animaloc.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying animaloc.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying animaloc.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying animaloc.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/animaloc-0.2.1-py3.12.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing animaloc-0.2.1-py3.12.egg
# Removing /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg
# Copying animaloc-0.2.1-py3.12.egg to /usr/local/lib/python3.12/dist-packages
# Adding animaloc 0.2.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg
# Processing dependencies for animaloc==0.2.1
# Finished processing dependencies for animaloc==0.2.1

# %% [markdown]
# ## Create datasets

# %%
# Download some of the data of Delplanque et al. (2021) as an example
# !gdown 1CcTAZZJdwrBfCPJtVH6VBU3luGKIN9st -O /content/data.zip
# !unzip -oq /content/data.zip -d /content
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1CcTAZZJdwrBfCPJtVH6VBU3luGKIN9st
# From (redirected): https://drive.google.com/uc?id=1CcTAZZJdwrBfCPJtVH6VBU3luGKIN9st&confirm=t&uuid=2050f81b-b33f-48b4-93c2-b9c544cb408e
# To: /content/data.zip
# 100% 11.6G/11.6G [05:24<00:00, 35.6MB/s]

# %%
# Set the seed
from animaloc.utils.seed import set_seed

set_seed(9292)

# %%
# Create validation patches using the patcher tool (for demo)
from animaloc.utils.useful_funcs import mkdir

mkdir('/content/data/val_patches')
# !python /content/HerdNet/tools/patcher.py /content/data/val 512 512 0 /content/data/val_patches -csv /content/data/val.csv -min 0.0 -all False
# Out:
# Creating the buffer: 100% 111/111 [01:16<00:00,  1.45it/s]
# Exporting patches: 100% 111/111 [03:13<00:00,  1.74s/it]

# %%
# Training, validation and test datasets
import albumentations as A

from animaloc.datasets import CSVDataset
from animaloc.data.transforms import MultiTransformsWrapper, DownSample, PointsToMask, FIDT

patch_size = 512
num_classes = 7
down_ratio = 2

train_dataset = CSVDataset(
    csv_file = '/content/data/train_patches.csv',
    root_dir = '/content/data/train_patches',
    albu_transforms = [
        A.VerticalFlip(p=0.5),
        A.HorizontalFlip(p=0.5),
        A.RandomRotate90(p=0.5),
        A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.2),
        A.Blur(blur_limit=15, p=0.2),
        A.Normalize(p=1.0)
        ],
    end_transforms = [MultiTransformsWrapper([
        FIDT(num_classes=num_classes, down_ratio=down_ratio),
        PointsToMask(radius=2, num_classes=num_classes, squeeze=True, down_ratio=int(patch_size//16))
        ])]
    )

val_dataset = CSVDataset(
    csv_file = '/content/data/val_patches/gt.csv',
    root_dir = '/content/data/val_patches',
    albu_transforms = [A.Normalize(p=1.0)],
    end_transforms = [DownSample(down_ratio=down_ratio, anno_type='point')]
    )

test_dataset = CSVDataset(
    csv_file = '/content/data/test.csv',
    root_dir = '/content/data/test',
    albu_transforms = [A.Normalize(p=1.0)],
    end_transforms = [DownSample(down_ratio=down_ratio, anno_type='point')]
    )

# %%
# Dataloaders
from torch.utils.data import DataLoader

train_dataloader = DataLoader(dataset = train_dataset, batch_size = 4, shuffle = True)

val_dataloader = DataLoader(dataset = val_dataset, batch_size = 1, shuffle = False)

test_dataloader = DataLoader(dataset = test_dataset, batch_size = 1, shuffle = False)

# %% [markdown]
# ## Define HerdNet for training

# %%
from animaloc.models import HerdNet
from torch import Tensor
from animaloc.models import LossWrapper
from animaloc.train.losses import FocalLoss
from torch.nn import CrossEntropyLoss

herdnet = HerdNet(num_classes=num_classes, down_ratio=down_ratio).cuda()

weight = Tensor([0.1, 1.0, 2.0, 1.0, 6.0, 12.0, 1.0]).cuda()

losses = [
    {'loss': FocalLoss(reduction='mean'), 'idx': 0, 'idy': 0, 'lambda': 1.0, 'name': 'focal_loss'},
    {'loss': CrossEntropyLoss(reduction='mean', weight=weight), 'idx': 1, 'idy': 1, 'lambda': 1.0, 'name': 'ce_loss'}
    ]

herdnet = LossWrapper(herdnet, losses=losses)
# Out:
# Downloading: "http://dl.yf.io/dla/models/imagenet/dla34-ba72cf86.pth" to /root/.cache/torch/hub/checkpoints/dla34-ba72cf86.pth
# 100%|██████████| 60.3M/60.3M [00:09<00:00, 6.74MB/s]

# %% [markdown]
# ## Create the Trainer

# %%
from torch.optim import Adam
from animaloc.train import Trainer
from animaloc.eval import PointsMetrics, HerdNetStitcher, HerdNetEvaluator
from animaloc.utils.useful_funcs import mkdir

work_dir = '/content/output'
mkdir(work_dir)

lr = 1e-4
weight_decay = 1e-3
epochs = 100

optimizer = Adam(params=herdnet.parameters(), lr=lr, weight_decay=weight_decay)

metrics = PointsMetrics(radius=20, num_classes=num_classes)

stitcher = HerdNetStitcher(
    model=herdnet,
    size=(patch_size,patch_size),
    overlap=160,
    down_ratio=down_ratio,
    reduction='mean'
    )

evaluator = HerdNetEvaluator(
    model=herdnet,
    dataloader=val_dataloader,
    metrics=metrics,
    stitcher=stitcher,
    work_dir=work_dir,
    header='validation'
    )

trainer = Trainer(
    model=herdnet,
    train_dataloader=train_dataloader,
    optimizer=optimizer,
    num_epochs=epochs,
    evaluator=evaluator,
    work_dir=work_dir
    )

# %% [markdown]
# ## Start training

# %%
trainer.start(warmup_iters=100, checkpoints='best', select='max', validate_on='f1_score')
# Out:
# INFO:20260128_training:[TRAINING] - Epoch: [1] [   1/1942] eta: 1:04:21 lr: 0.000002 loss: 9301.1689 (9301.1689) focal_loss: 9299.1328 (9299.1328) ce_loss: 2.0361 (2.0361) time: 1.9883 data: 0.1937 max mem: 2222
# [TRAINING] - Epoch: [1] [   1/1942] eta: 1:04:21 lr: 0.000002 loss: 9301.1689 (9301.1689) focal_loss: 9299.1328 (9299.1328) ce_loss: 2.0361 (2.0361) time: 1.9883 data: 0.1937 max mem: 2222
# INFO:20260128_training:[TRAINING] - Epoch: [1] [  51/1942] eta: 0:12:56 lr: 0.000051 loss: 6203.9312 (7708.6873) focal_loss: 6202.1128 (7706.9366) ce_loss: 1.6201 (1.7507) time: 0.3704 data: 0.1151 max mem: 2368
# [TRAINING] - Epoch: [1] [  51/1942] eta: 0:12:56 lr: 0.000051 loss: 6203.9312 (7708.6873) focal_loss: 6202.1128 (7706.9366) ce_loss: 1.6201 (1.7507) time: 0.3704 data: 0.1151 max mem: 2368
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2317459279.py in <cell line: 0>()
# ----> 1 trainer.start(warmup_iters=100, checkpoints='best', select='max', validate_on='f1_score')
#
# /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg/animaloc/train/trainers.py in start(self, warmup_iters, checkpoints, select, validate_on, wandb_flag)
#     271
#     272             # training
# --> 273             train_output = self._train(epoch, warmup_iters, wandb_flag)
#     274             if wandb_flag:
#     275                 wandb.log({'train_loss': train_output, 'epoch': epoch})
#
# /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg/animaloc/train/trainers.py in _train(self, epoch, warmup_iters, wandb_flag)
#     512         batches_losses = []
#     513
# --> 514         for images, targets in self.train_logger.log_every(self.train_dataloader, self.print_freq, header):
#     515
#     516             images, targets = self.prepare_data(images, targets)
#
# /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg/animaloc/utils/logger.py in log_every(self, iterable, print_freq, header)
#      71         MB = 1024.0 * 1024.0
#      72         flag = 1
# ---> 73         for obj in iterable:
#      74             data_time.update(time.time() - end)
#      75             yield obj
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     730                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731                 self._reset()  # type: ignore[call-arg]
# --> 732             data = self._next_data()
#     733             self._num_yielded += 1
#     734             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     786     def _next_data(self):
#     787         index = self._next_index()  # may raise StopIteration
# --> 788         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789         if self._pin_memory:
#     790             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg/animaloc/datasets/csv.py in __getitem__(self, index)
#     227         target = self._load_target(index)
#     228
# --> 229         tr_img, tr_target = self._transforms(img, target)
#     230
#     231         return tr_img, tr_target
#
# /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg/animaloc/datasets/csv.py in _transforms(self, image, target)
#     216                 if self.end_transforms is not None:
#     217                     for trans in self.end_transforms:
# --> 218                         tr_image, tr_target = trans(tr_image, tr_target)
#     219
#     220                 return tr_image, tr_target
#
# /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg/animaloc/data/transforms.py in __call__(self, image, target)
#      67         outputs = []
#      68         for trans in self.transforms:
# ---> 69             img, tr_trgt = trans(image, target)
#      70             outputs.append(tr_trgt)
#      71
#
# /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg/animaloc/data/transforms.py in __call__(self, image, target)
#     370             dist_map = self._onehot(image, new_target)
#     371         else:
# --> 372             dist_map = self._onehot(image, target)
#     373
#     374         if self.add_bg:
#
# /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg/animaloc/data/transforms.py in _onehot(self, image, target)
#     401             dist_maps = torch.ones((self.num_classes, self.img_height, self.img_width), dtype=torch.float64)
#     402             for i, mask in enumerate(masks):
# --> 403                 mask = self._get_fidt(mask)
#     404                 if i+1 in labels:
#     405                     dist_maps[i] = mask
#
# /usr/local/lib/python3.12/dist-packages/animaloc-0.2.1-py3.12.egg/animaloc/data/transforms.py in _get_fidt(self, mask)
#     379     def _get_fidt(self, mask: torch.Tensor) -> torch.Tensor:
#     380
# --> 381         dist_map = scipy.ndimage.distance_transform_edt(mask)
#     382         dist_map = torch.from_numpy(dist_map)
#     383         dist_map = 1 / (torch.pow(dist_map, self.alpha * dist_map + self.beta) + self.c)
#
# /usr/local/lib/python3.12/dist-packages/scipy/ndimage/_morphology.py in distance_transform_edt(input, sampling, return_distances, return_indices, distances, indices)
#    2600             np.sqrt(dt, distances)
#    2601         else:
# -> 2602             dt = np.add.reduce(dt, axis=0)
#    2603             dt = np.sqrt(dt)
#    2604
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test the model

# %% [markdown]
# Download the model from here:
# https://dataverse.uliege.be/file.xhtml?fileId=28088&version=1.0

# %%
pth_path = '/content/20220413_HerdNet_General_dataset_2022.pth'

# %%
# Create output folder
test_dir = '/content/test_output'
mkdir(test_dir)

# %%
# Load trained parameters
from animaloc.models import load_model

herdnet = load_model(herdnet, pth_path=pth_path)

# %%
# Create an Evaluator
test_evaluator = HerdNetEvaluator(
    model=herdnet,
    dataloader=test_dataloader,
    metrics=metrics,
    stitcher=stitcher,
    work_dir=test_dir,
    header='test'
    )

# %%
# Start testing
test_f1_score = test_evaluator.evaluate(returns='f1_score')
# Out:
# INFO:20260128_evaluation:test [  1/258] eta: 0:30:40 n: 1 recall: 1.0 precision: 0.2 f1-score: 0.33 MAE: 4.0 MSE: 16.0 RMSE: 4.0 time: 7.1319 data: 1.1527 max mem: 2368
# test [  1/258] eta: 0:30:40 n: 1 recall: 1.0 precision: 0.2 f1-score: 0.33 MAE: 4.0 MSE: 16.0 RMSE: 4.0 time: 7.1319 data: 1.1527 max mem: 2368
# INFO:20260128_evaluation:test [ 11/258] eta: 0:27:23 n: 1 recall: 1.0 precision: 1.0 f1-score: 1.0 MAE: 0.0 MSE: 0.0 RMSE: 0.0 time: 6.6257 data: 1.1405 max mem: 2368
# test [221/258] eta: 0:04:00 n: 2 recall: 1.0 precision: 0.67 f1-score: 0.8 MAE: 1.0 MSE: 1.0 RMSE: 1.0 time: 5.7053 data: 1.0463 max mem: 2368
# INFO:20260128_evaluation:test [231/258] eta: 0:02:56 n: 7 recall: 0.43 precision: 0.38 f1-score: 0.4 MAE: 1.0 MSE: 1.0 RMSE: 1.0 time: 5.6893 data: 1.0579 max mem: 2368
# test [231/258] eta: 0:02:56 n: 7 recall: 0.43 precision: 0.38 f1-score: 0.4 MAE: 1.0 MSE: 1.0 RMSE: 1.0 time: 5.6893 data: 1.0579 max mem: 2368
# INFO:20260128_evaluation:test [241/258] eta: 0:01:52 n: 13 recall: 0.46 precision: 0.86 f1-score: 0.6 MAE: 6.0 MSE: 36.0 RMSE: 6.0 time: 5.7081 data: 1.0227 max mem: 2368
# test [241/258] eta: 0:01:52 n: 13 recall: 0.46 precision: 0.86 f1-score: 0.6 MAE: 6.0 MSE: 36.0 RMSE: 6.0 time: 5.7081 data: 1.0227 max mem: 2368
# INFO:20260128_evaluation:test [251/258] eta: 0:00:50 n: 2 recall: 1.0 precision: 1.0 f1-score: 1.0 MAE: 0.0 MSE: 0.0 RMSE: 0.0 time: 5.7926 data: 1.0140 max mem: 2368
# test [251/258] eta: 0:00:50 n: 2 recall: 1.0 precision: 1.0 f1-score: 1.0 MAE: 0.0 MSE: 0.0 RMSE: 0.0 time: 5.7926 data: 1.0140 max mem: 2368
# INFO:20260128_evaluation:test [258/258] eta: 0:00:06 n: 3 recall: 0.67 precision: 0.67 f1-score: 0.67 MAE: 0.0 MSE: 0.0 RMSE: 0.0 time: 5.7690 data: 1.0238 max mem: 2368
# INFO:20260128_evaluation:test Total time: 0:26:50 (6.2430 s / it)
# test [258/258] eta: 0:00:06 n: 3 recall: 0.67 precision: 0.67 f1-score: 0.67 MAE: 0.0 MSE: 0.0 RMSE: 0.0 time: 5.7690 data: 1.0238 max mem: 2368
# test Total time: 0:26:50 (6.2430 s / it)

# %%
# Print global F1 score (%)
print(f"F1 score = {test_f1_score * 100:0.0f}%")
# Out:
# F1 score = 83%

# %%
# Get the detections
detections = test_evaluator.results
detections
# Out:
#     class     n    recall  precision  f1_score  confusion       mae  \
# 0       1   675  0.878519   0.838755  0.858177   0.054226  1.718310
# 1       2   349  0.727794   0.916968  0.811502   0.066176  3.500000
# 2       3   477  0.903564   0.850099  0.876016   0.092632  1.018868
# 3       4    74  0.445946   0.388235  0.415094   0.057143  2.243243
# 4       5    36  0.694444   0.675676  0.684932   0.193548  1.250000
# 5       6   688  0.728198   0.676113  0.701190   0.001992  2.572816
# 6  binary  2299  0.844715   0.824979  0.834730   0.000000  1.895349
#
#          mse      rmse        ap
# 0   7.887324  2.808438  0.804623
# 1  35.642857  5.970164  0.693974
# 2   3.924528  1.981042  0.859548
# 3   9.810811  3.132221  0.272273
# 4   2.250000  1.500000  0.596373
# 5  19.485437  4.414231  0.655624
# 6  13.468992  3.670013  0.723480
